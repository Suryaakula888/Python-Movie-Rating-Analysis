# %%
# Movie Rating Analysis
import pandas as pd
pd.__version__
# Out:
# '1.2.4'

# %%
import numpy as np
np.__version__
# Out:
# '1.21.0'

# %%
movie = pd.read_csv(r"E:\Naresh IT\DataSets\Movie-Rating.csv")

# %%
movie
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movie.isnull().sum()
# Out:
# Film                         0
# Genre                        0
# Rotten Tomatoes Ratings %    0
# Audience Ratings %           0
# Budget (million $)           0
# Year of release              0
# dtype: int64

# %%
movie.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movie.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
len(movie.columns)
# Out:
# 6

# %%
movie.shape
# Out:
# (559, 6)

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
len(movie)
# Out:
# 559

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating',
       'BudgetMillion', 'Year']

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillion',
#        'Year'],
#       dtype='object')

# %%
movie.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movie.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillion         Year
# count    559.000000      559.000000     559.000000   559.000000
# mean      47.309481       58.744186      50.236136  2009.152057
# std       26.413091       16.826887      48.731817     1.362632
# min        0.000000        0.000000       0.000000  2007.000000
# 25%       25.000000       47.000000      20.000000  2008.000000
# 50%       46.000000       58.000000      35.000000  2009.000000
# 75%       70.000000       72.000000      65.000000  2010.000000
# max       97.000000       96.000000     300.000000  2011.000000

# %%
movie["Year"] = movie["Year"].astype("category")
movie["Film"] = movie["Film"].astype("category")
movie["Genre"] = movie["Genre"].astype("category")

# %%
movie.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillion   559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movie.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillion
# count    559.000000      559.000000     559.000000
# mean      47.309481       58.744186      50.236136
# std       26.413091       16.826887      48.731817
# min        0.000000        0.000000       0.000000
# 25%       25.000000       47.000000      20.000000
# 50%       46.000000       58.000000      35.000000
# 75%       70.000000       72.000000      65.000000
# max       97.000000       96.000000     300.000000

# %%
# how to work with joint plots
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
j=sns.jointplot(data=movie,x="CriticRating",y="AudienceRating")
# audience rating is more dominence than critics rating
# positve corelation between two attributes

# %%
j=sns.jointplot(data=movie,x="CriticRating",y="AudienceRating",kind="scatter") # kind -> parameter # bydefault scatter

# %%
j=sns.jointplot(data=movie,x="CriticRating",y="AudienceRating",kind="hex")

# %%
j=sns.jointplot(data=movie,x="CriticRating",y="AudienceRating",kind="reg") # bell curve line graph

# %%
j=sns.jointplot(data=movie,x="CriticRating",y="AudienceRating",kind="kde") # kernal density plot

# %%
j=sns.jointplot(data=movie,x="CriticRating",y="AudienceRating",kind="hex")

# %%
m1 = sns.distplot(movie.AudienceRating) # normal distribution # univariete

# %%
m2=sns.distplot(movie.CriticRating)

# %%
m3=sns.displot(movie.AudienceRating)

# %%
m4 = sns.boxplot(movie.AudienceRating)

# %%
m5=sns.displot(movie.CriticRating)

# %%
sns.set_style('darkgrid')

# %%
m5=sns.displot(movie.CriticRating)

# %%
m6=sns.displot(movie.CriticRating,bins=10)

# %%
m6=sns.displot(movie.CriticRating,bins=15)

# %%
sns.set_style("white")

# %%
m7=sns.displot(movie.AudienceRating)

# %%
m8 = plt.hist(movie.CriticRating,bins=10)

# %%
plt.hist(movie.BudgetMillion)
plt.show()

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillion',
#        'Year'],
#       dtype='object')

# %%
plt.hist(movie[movie.Genre == "Drama"].BudgetMillion)
# Out:
# (array([25., 40., 18.,  8.,  6.,  2.,  1.,  0.,  0.,  1.]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(movie[movie.Genre == "Drama"].BudgetMillion)
plt.show()

# %%
movie.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']

# %%
# Below plots are stacked histogram becuase overlaped

plt.hist(movie[movie.Genre == 'Action'].BudgetMillion, bins = 20)
plt.hist(movie[movie.Genre == 'Thriller'].BudgetMillion, bins = 20)
plt.hist(movie[movie.Genre == 'Drama'].BudgetMillion, bins = 20)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.hist([movie[movie.Genre == 'Action'].BudgetMillion,\
          movie[movie.Genre == 'Drama'].BudgetMillion, \
          movie[movie.Genre == 'Thriller'].BudgetMillion, \
          movie[movie.Genre == 'Comedy'].BudgetMillion],
         bins = 20, stacked = True)
plt.show()

# %%
# if you have 100 categories you cannot copy & paste all the things

for gen in movie.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1 = sns.lmplot(data=movie, x='CriticRating', y='AudienceRating', fit_reg=False)

# %%
vis1 = sns.lmplot(data=movie, x='CriticRating', y='AudienceRating',fit_reg=False, hue = 'Genre')

# %%
plt.style.use('dark_background')
vis1 = sns.lmplot(data=movie, x='CriticRating', y='AudienceRating',fit_reg=False, hue = 'Genre', height= 10,aspect=1)

# %%
# Kernal Density Estimate plot ( KDE PLOT) 
# how can i visulize audience rating & critics rating . using scatterplot
plt.style.use('default')

# %%
k1 = sns.kdeplot(data = movie,x ='CriticRating',y ='AudienceRating' )

# where do u find more density and how density is distibuted across from the the chat 
# center point is kernal this is calld KDE & insteade of dots it visualize like this
# we can able to clearly see the spread at the audience ratings

# %%
k1 = sns.kdeplot(data=movie, x='CriticRating', y='AudienceRating', shade=True, shade_lowest=False, cmap='Reds')

# %%
k2 = sns.kdeplot(data = movie, x= 'CriticRating', y= 'AudienceRating',shade_lowest=False,cmap='Greens_r')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(data = movie, x = 'BudgetMillion',y ='AudienceRating')

# %%
#subplots

f, ax = plt.subplots(1,2, figsize =(12,6))

# %%
f, axes = plt.subplots(1,2, figsize =(12,6))

k1 = sns.kdeplot(data = movie,x ='BudgetMillion',y = 'AudienceRating',ax=axes[0])
k2 = sns.kdeplot(data = movie,x ='BudgetMillion',y = 'CriticRating',ax = axes[1])

# %%
#Box plots - 

w = sns.boxplot(data=movie, x='Genre', y = 'CriticRating')

# %%
#violin plot
z = sns.violinplot(data=movie, x='Genre', y = 'CriticRating')

# %%
w1 = sns.boxplot(data=movie[movie.Genre == 'Drama'], x='Year', y = 'CriticRating')

# %%
z = sns.violinplot(data=movie[movie.Genre == 'Drama'], x='Year', y = 'CriticRating')

# %%
# Createing a Facet grid
plt.style.use('default')

# %%
g =sns.FacetGrid (movie, row = 'Genre', col = 'Year', hue = 'Genre') #kind of subplots

# %%
plt.style.use('dark_background')
plt.scatter(movie.CriticRating,movie.AudienceRating)

# %%
plt.style.use('dark_background')
g =sns.FacetGrid (movie, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating' ) 

# scatterplots are mapped in facetgrid

# %%
# you can populated any type of chat. 

g =sns.FacetGrid (movie, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillion') #scatterplots are mapped in facetgrid

# %%
g =sns.FacetGrid (movie, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws ) #scatterplots are mapped in facetgrid

# %%
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (8,8))

k1 = sns.kdeplot(x = movie.BudgetMillion,y = movie.AudienceRating,ax=axes[0,0])
k2 = sns.kdeplot(x = movie.BudgetMillion,y = movie.CriticRating,ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=movie[movie.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])

k4 = sns.kdeplot(x = movie.CriticRating,y=movie.AudienceRating,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(x = movie.CriticRating,y = movie.AudienceRating,cmap='Reds',ax = axes[1,1])

plt.show()
